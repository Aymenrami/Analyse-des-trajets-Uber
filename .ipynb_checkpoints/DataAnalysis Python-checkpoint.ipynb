# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DataUber.csv')
df
# Out:
#          Base      Lat      Lon Nom du jour  Jour de la semaine  Heure  \
# 0      B02512  40.6691 -73.9897      Sunday                   0      0
# 1      B02512  40.6691 -73.9808      Sunday                   0      0
# 2      B02512  40.6721 -73.9870      Sunday                   0      0
# 3      B02512  40.6739 -73.9761      Sunday                   0      0
# 4      B02512  40.6787 -73.9686      Sunday                   0      0
# ...       ...      ...      ...         ...                 ...    ...
# 29995  B02512  40.7772 -73.9619    Saturday                   6     18
# 29996  B02512  40.7783 -73.9850    Saturday                   6     18
# 29997  B02512  40.7787 -73.9559    Saturday                   6     18
# 29998  B02512  40.7788 -73.9620    Saturday                   6     18
# 29999  B02512  40.7789 -73.9601    Saturday                   6     18
#
#          DayType Nom du mois DaySituation
# 0      NormalDay   September        Night
# ...

# %%
sns.histplot(df['Jour de la semaine'],kde = True)
plt.xticks(rotation = 0)
plt.show()

# %%
sns.histplot(df['Heure'],kde = True)
# Out:
# <Axes: xlabel='Heure', ylabel='Count'>

# %%
g=sns.FacetGrid(df, col='DayType')
g.map(sns.histplot, 'Heure' , kde = True)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
count= df['DayType'].value_counts()
plt.pie(count ,startangle= 90 , autopct='%.0f%%',colors =['#2D3250','#F6B17A'] , shadow=True)
plt.legend(labels=count.index, loc='upper right', bbox_to_anchor=(1.1,1))
plt.show()

# %%
corre = df.groupby(['Nom du jour' , 'Heure']).apply(lambda x: len(x))
corre=corre.unstack()
sns.heatmap(corre)
plt.show()

# %%
sns.scatterplot(x='Lon' , y ='Lat', data= df , size = df.index )
# Out:
# <Axes: xlabel='Lon', ylabel='Lat'>
